# %% [markdown]
# <a href="https://colab.research.google.com/github/amantiwari57/3d-web/blob/master/dev/lite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ========================================
# WORKING STABLE DIFFUSION WEBUI FOR COLAB
# Fixed for January 2025 - Stability-AI repo issue
# ========================================

# %cd /content

# Clean up
# !rm -rf /content/stable-diffusion-webui
# %env LD_PRELOAD=

# THE FIX: Set environment variable to use working fork
# %env STABLE_DIFFUSION_REPO=https://github.com/w-e-w/stablediffusion.git

# Install system dependencies
# !apt -y update -qq
# !apt -y install -qq aria2 wget git

# Install PyTorch
# !pip install -q torch==2.0.1+cu118 torchvision==0.15.2+cu118 --extra-index-url https://download.pytorch.org/whl/cu118
# !pip install -q xformers==0.0.20 triton==2.0.0

# Clone WebUI
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui /content/stable-diffusion-webui

# %cd /content/stable-diffusion-webui

# Download model (SD 1.5)
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M \
  https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.safetensors \
  -d /content/stable-diffusion-webui/models/Stable-diffusion \
  -o v1-5-pruned-emaonly.safetensors

# Download VAE
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M \
  https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors \
  -d /content/stable-diffusion-webui/models/VAE \
  -o vae-ft-mse-840000-ema-pruned.safetensors

print("\n" + "="*60)
print("LAUNCHING STABLE DIFFUSION WEBUI")
print("Using working fork: w-e-w/stablediffusion")
print("="*60 + "\n")

# FIX matplotlib backend crash
# %env MPLBACKEND=Agg
# !pip install -q matplotlib==3.7.3

# Launch WebUI
# !STABLE_DIFFUSION_REPO=https://github.com/w-e-w/stablediffusion.git python launch.py \
  --listen \
  --xformers \
  --enable-insecure-extension-access \
  --gradio-queue \
  --skip-torch-cuda-test \
  --no-half-vae \
  --share
